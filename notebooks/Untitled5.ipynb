# %%
# Out:
# /opt/exoplanet/venv/lib/python3.12/site-packages/lightkurve/prf/__init__.py:7: UserWarning: Warning: the tpfmodel submodule is not available without oktopus installed, which requires a current version of autograd. See #1452 for details.
#   warnings.warn(
# Fetching TIC 349095149 (TOI-1221 b, confirmed planet)...
# This is a confirmed sub-Neptune with a 91.7-day orbit.
# It was published in the Astronomical Journal in 2023.
# The third transit that confirmed the period was in Sector 10.
